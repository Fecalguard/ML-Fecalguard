# %% [markdown]
# # ML - Fecalguard
#
# Sumber Dataset: https://www.kaggle.com/datasets/allandclive/chicken-disease-1

# %% [markdown]
# ## Import Library

# %%
import shutil
from google.colab import files

import matplotlib.pyplot as plt
import numpy as np
import os
import shutil
import kagglehub
import io
import pandas as pd
import seaborn as sns
from pathlib import Path
import matplotlib.image as mpimg
import random

from collections import defaultdict, Counter
from PIL import Image

from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, models, optimizers
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, BatchNormalization
from tensorflow.keras.applications import DenseNet121
from tensorflow.keras import layers, models, optimizers, Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau

# %% [markdown]
# ## Data Loading

# %%
# Download latest version
path = kagglehub.dataset_download("allandclive/chicken-disease-1")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: /kaggle/input/chicken-disease-1

# %%
df = pd.read_csv('/kaggle/input/chicken-disease-1/train_data.csv')
df.sample(10)
# Out:
#                  images               label
# 4966     salmo.1985.jpg          Salmonella
# 860      salmo.1400.jpg          Salmonella
# 6980      salmo.942.jpg          Salmonella
# 2727      salmo.630.jpg          Salmonella
# 3605     cocci.1003.jpg         Coccidiosis
# 857       salmo.404.jpg          Salmonella
# 2984  pcrhealthy.84.jpg             Healthy
# 3570      pcrncd.30.jpg  New Castle Disease
# 2135     pcrncd.147.jpg  New Castle Disease
# 5001   healthy.1496.jpg             Healthy

# %%
df['label'].value_counts()
# Out:
# label
# Salmonella            2625
# Coccidiosis           2476
# Healthy               2404
# New Castle Disease     562
# Name: count, dtype: int64

# %%
# menghitung jumlah data & resolusi data dalam dataset
dataset_path = "/kaggle/input/chicken-disease-1"

# inisialisasi variabel penampung
label_counts = defaultdict(int)
resolution_counter = Counter()
resolution_per_label = defaultdict(set)

# loop menghitung jumlah data & resolusi data dalam dataset
for label in os.listdir(dataset_path):
    label_dir = os.path.join(dataset_path, label)
    if os.path.isdir(label_dir):
        for img_name in os.listdir(label_dir):
            img_path = os.path.join(label_dir, img_name)
            try:
                with Image.open(img_path) as img:
                    label_counts[label] += 1
                    resolution = img.size  # (width, height)
                    resolution_counter[resolution] += 1
                    resolution_per_label[label].add(resolution)
            except Exception as e:
                print(f"Gagal membuka {img_path}: {e}")

# %%
print("\nResolusi gambar dalam dataset:")
for label, resolutions in resolution_per_label.items():
    print(f"{label}: {list(resolutions)}\n")
# Out:
# Resolusi gambar dalam dataset:
# Train: [(224, 224)]

# %%
FOLDER = Path("/kaggle/input/chicken-disease-1/Train")

# ambil semua file JPG, lalu acak
all_images = list(FOLDER.rglob("*.jpg"))      # rglob agar menangkap subfolder per-label
random.shuffle(all_images)
selected = all_images[:10]

plt.figure(figsize=(15,8))
for i, img_path in enumerate(selected, 1):
    img = mpimg.imread(img_path)
    plt.subplot(2,5,i)
    plt.imshow(img); plt.axis("off")
    plt.title(f"{img_path.parent.name}\n{img_path.name}", fontsize=9)  # tampilkan label & nama file
plt.tight_layout(); plt.show()

# %% [markdown]
# ## Data Splitting

# %% [markdown]
# split ratio
#
# train:val:test = 80:15:15

# %%
train_df, test_df = train_test_split(df, test_size=0.15, stratify=df['label'], random_state=42)
train_df, val_df  = train_test_split(train_df, test_size=0.15, stratify=train_df['label'], random_state=42)

print(f"Train {train_df['label'].value_counts()} \n")
print(f"Val {val_df['label'].value_counts()} \n")
print(f"Test {test_df['label'].value_counts()} \n")
# Out:
# Train label
# Salmonella            1896
# Coccidiosis           1788
# Healthy               1737
# New Castle Disease     406
# Name: count, dtype: int64
#
# Val label
# Salmonella            335
# Coccidiosis           316
# Healthy               306
# New Castle Disease     72
# Name: count, dtype: int64
#
# Test label
# Salmonella            394
# Coccidiosis           372
# Healthy               361
# New Castle Disease     84
# Name: count, dtype: int64

# %% [markdown]
# ## Data Augmentation

# %%
df = pd.read_csv('/kaggle/input/chicken-disease-1/train_data.csv')
print(df.columns)
# Out:
# Index(['images', 'label'], dtype='object')

# %%
train_datagen = ImageDataGenerator(
    rescale        = 1./255,
    rotation_range = 20,
    width_shift_range  = 0.1,
    height_shift_range = 0.1,
    shear_range    = 0.1,
    zoom_range     = 0.1,
    horizontal_flip=True
)

val_test_datagen = ImageDataGenerator(rescale=1./255)

train_gen = train_datagen.flow_from_dataframe(
    train_df,
    directory='/kaggle/input/chicken-disease-1/Train',
    x_col='images',
    y_col='label',
    target_size=(244,244),
    class_mode='categorical',
    batch_size=32
)

val_gen = val_test_datagen.flow_from_dataframe(
    val_df, directory='/kaggle/input/chicken-disease-1/Train',
    x_col='images',
    y_col='label',
    target_size=(244,244),
    class_mode='categorical',
    batch_size=32, shuffle=False
)

test_gen = val_test_datagen.flow_from_dataframe(
    test_df, directory='/kaggle/input/chicken-disease-1/Train',
    x_col='images',
    y_col='label',
    target_size=(244,244),
    class_mode='categorical',
    batch_size=32, shuffle=False
)
# Out:
# Found 5827 validated image filenames belonging to 4 classes.
# Found 1029 validated image filenames belonging to 4 classes.
# Found 1211 validated image filenames belonging to 4 classes.

# %% [markdown]
# ## Modelling

# %%
# Membuat base model menggunakan DenseNet121
base_model = DenseNet121(weights='imagenet', include_top=False, input_shape=(244, 244, 3), pooling= 'max')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet121_weights_tf_dim_ordering_tf_kernels_notop.h5
# 29084464/29084464 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
# Membekukan lapisan-lapisan pada base model agar tidak terlatih pada awalnya
base_model.trainable = False

# %%
# Fungsi untuk membangun model CNN dengan DenseNet121 sebagai base model
def build_cnn_with_densenet121(input_shape=(244, 244, 3), num_classes=4):
    # Memuat model DenseNet121 tanpa lapisan top (fully connected)
    base_model = DenseNet121(weights='imagenet', include_top=False, input_shape=input_shape)

    # Membekukan lapisan-lapisan pada base model agar tidak terlatih selama pelatihan awal
    base_model.trainable = False

    # Membangun model Sequential
    model = models.Sequential([
        base_model,  # Menambahkan DenseNet121 sebagai base model
        layers.GlobalAveragePooling2D(),  # Menggunakan pooling untuk mereduksi dimensi
        layers.Dense(256, activation='relu'),  # Lapisan Dense untuk klasifikasi
        layers.BatchNormalization(),  # Normalisasi untuk stabilitas pelatihan
        layers.Dense(128, activation='relu'),
        layers.Dense(64, activation='relu'),
        layers.Dropout(0.2),  # Dropout untuk mengurangi overfitting
        layers.Dense(num_classes, activation='softmax')  # Lapisan output untuk klasifikasi
    ])

    # Menyusun model
    model.compile(optimizer=Adam(learning_rate=0.0001),
                  loss='categorical_crossentropy',  # Fungsi loss untuk klasifikasi multi-kelas
                  metrics=['accuracy'])

    # Menampilkan ringkasan model
    model.summary()

    return model

# %%
# Membangun model awal
model = build_cnn_with_densenet121()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ densenet121 (Functional)        │ (None, 7, 7, 1024)     │     7,037,504 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 1024)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │       262,400 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 4)              │           260 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 7,342,340 (28.01 MB)
#  Trainable params: 304,324 (1.16 MB)
#  Non-trainable params: 7,038,016 (26.85 MB)

# %%
# Fine-tuning setelah pelatihan awal
base_model.trainable = True

# %%
# Fine-tuning setelah pelatihan awal
# Membuka kembali lapisan-lapisan base model untuk fine-tuning
base_model = model.layers[0]  # Mendapatkan base model MobileNetV2 dari model

base_model.trainable = True

# %%
# Membekukan semua lapisan kecuali 20 lapisan terakhir
for layer in base_model.layers[:-20]:
    layer.trainable = False

# %%
# Menyusun ulang model setelah fine-tuning
model.compile(optimizer=Adam(learning_rate=0.00001),  # Gunakan learning rate lebih kecil
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
history = model.fit(
    train_gen,
    epochs=30,
    validation_data=val_gen,
    callbacks=[
        tf.keras.callbacks.EarlyStopping(patience=5, restore_best_weights=True)
    ]
)
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/30
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 159s 679ms/step - accuracy: 0.3366 - loss: 1.7023 - val_accuracy: 0.4402 - val_loss: 1.2866
# Epoch 2/30
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 89s 483ms/step - accuracy: 0.4237 - loss: 1.3262 - val_accuracy: 0.5743 - val_loss: 1.0533
# Epoch 3/30
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 88s 480ms/step - accuracy: 0.5789 - loss: 1.0324 - val_accuracy: 0.6686 - val_loss: 0.8933
# Epoch 4/30
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 89s 486ms/step - accuracy: 0.6642 - loss: 0.8788 - val_accuracy: 0.7182 - val_loss: 0.7828
# Epoch 5/30
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 86s 472ms/step - accuracy: 0.7146 - loss: 0.7907 - val_accuracy: 0.7600 - val_loss: 0.6877
# Epoch 6/30
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 88s 479ms/step - accuracy: 0.7511 - loss: 0.7011 - val_accuracy: 0.7823 - val_loss: 0.6219
# Epoch 7/30
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 87s 475ms/step - accuracy: 0.7803 - loss: 0.6289 - val_accuracy: 0.8008 - val_loss: 0.5697
# Epoch 8/30
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 86s 472ms/step - accuracy: 0.7987 - loss: 0.5924 - val_accuracy: 0.8192 - val_loss: 0.5261
# Epoch 9/30
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 88s 480ms/step - accuracy: 0.8066 - loss: 0.5550 - val_accuracy: 0.8280 - val_loss: 0.4959
# Epoch 10/30
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 87s 472ms/step - accuracy: 0.8154 - loss: 0.5274 - val_accuracy: 0.8387 - val_loss: 0.4603
# Epoch 11/30
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 89s 485ms/step - accuracy: 0.8150 - loss: 0.5063 - val_accuracy: 0.8562 - val_loss: 0.4303
# Epoch 12/30
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 87s 477ms/step - accuracy: 0.8331 - loss: 0.4695 - val_accuracy: 0.8630 - val_loss: 0.4079
# Epoch 13/30
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 87s 477ms/step - accuracy: 0.8451 - loss: 0.4421 - val_accuracy: 0.8678 - val_loss: 0.3872
# Epoch 14/30
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 89s 486ms/step - accuracy: 0.8632 - loss: 0.4074 - val_accuracy: 0.8756 - val_loss: 0.3653
# Epoch 15/30
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 89s 484ms/step - accuracy: 0.8676 - loss: 0.3869 - val_accuracy: 0.8795 - val_loss: 0.3490
# Epoch 16/30
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 87s 478ms/step - accuracy: 0.8739 - loss: 0.3884 - val_accuracy: 0.8853 - val_loss: 0.3341
# Epoch 17/30
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 90s 493ms/step - accuracy: 0.8783 - loss: 0.3633 - val_accuracy: 0.8892 - val_loss: 0.3225
# Epoch 18/30
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 87s 475ms/step - accuracy: 0.8814 - loss: 0.3588 - val_accuracy: 0.8912 - val_loss: 0.3129
# Epoch 19/30
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 89s 484ms/step - accuracy: 0.8818 - loss: 0.3318 - val_accuracy: 0.8941 - val_loss: 0.3054
# Epoch 20/30
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 87s 473ms/step - accuracy: 0.8898 - loss: 0.3116 - val_accuracy: 0.8999 - val_loss: 0.2954
# Epoch 21/30
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 88s 481ms/step - accuracy: 0.8981 - loss: 0.3099 - val_accuracy: 0.9009 - val_loss: 0.2870
# Epoch 22/30
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 86s 470ms/step - accuracy: 0.9035 - loss: 0.2944 - val_accuracy: 0.9038 - val_loss: 0.2818
# Epoch 23/30
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 88s 479ms/step - accuracy: 0.9017 - loss: 0.2891 - val_accuracy: 0.9077 - val_loss: 0.2751
# Epoch 24/30
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 87s 476ms/step - accuracy: 0.9043 - loss: 0.2906 - val_accuracy: 0.9096 - val_loss: 0.2712
# Epoch 25/30
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 88s 481ms/step - accuracy: 0.9122 - loss: 0.2590 - val_accuracy: 0.9125 - val_loss: 0.2645
# Epoch 26/30
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 88s 477ms/step - accuracy: 0.9108 - loss: 0.2624 - val_accuracy: 0.9135 - val_loss: 0.2582
# Epoch 27/30
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 88s 480ms/step - accuracy: 0.9220 - loss: 0.2418 - val_accuracy: 0.9164 - val_loss: 0.2518
# Epoch 28/30
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 90s 490ms/step - accuracy: 0.9204 - loss: 0.2340 - val_accuracy: 0.9184 - val_loss: 0.2494
# Epoch 29/30
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 89s 484ms/step - accuracy: 0.9201 - loss: 0.2371 - val_accuracy: 0.9203 - val_loss: 0.2464
# Epoch 30/30
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 88s 479ms/step - accuracy: 0.9237 - loss: 0.2290 - val_accuracy: 0.9193 - val_loss: 0.2417

# %% [markdown]
# ## Evaluation

# %%
# 1. Evaluasi test set
test_loss, test_acc = model.evaluate(test_gen)
print(f"Test Loss: {test_loss:.4f} | Test Accuracy: {test_acc:.4f}")

# 2. Plot kurva akurasi & loss
epochs_range = range(len(history.history['accuracy']))

plt.figure(figsize=(10,4))

# Accuracy
plt.subplot(1,2,1)
plt.plot(epochs_range, history.history['accuracy'], label='Train')
plt.plot(epochs_range, history.history['val_accuracy'], label='Val')
plt.title('Accuracy per Epoch')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

# Loss
plt.subplot(1,2,2)
plt.plot(epochs_range, history.history['loss'], label='Train')
plt.plot(epochs_range, history.history['val_loss'], label='Val')
plt.title('Loss per Epoch')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 19s 516ms/step - accuracy: 0.9078 - loss: 0.2562
# Test Loss: 0.2152 | Test Accuracy: 0.9282

# %%
from sklearn.metrics import classification_report, accuracy_score, precision_score, recall_score, f1_score

predictions = model.predict(test_gen)

# The predictions will be in a one-hot encoded format, so convert them to labels
predicted_classes = np.argmax(predictions, axis=1)

# Getting the true labels from the generator
true_classes = test_gen.labels

# Getting the class labels from the generator for later use in the classification report
class_labels = list(test_gen.class_indices.keys())

# Calculate and print the classification report
report = classification_report(true_classes, predicted_classes, target_names=class_labels)
accuracy = accuracy_score(true_classes, predicted_classes)

print(report)
print('Accuracy:', accuracy)
# Calculate Precision, Recall, and F1-Score
precision = precision_score(true_classes, predicted_classes, average='macro')
recall = recall_score(true_classes, predicted_classes, average='macro')
f1 = f1_score(true_classes, predicted_classes, average='macro')

print('Precision:', precision)
print('Recall:', recall)
print('F1-Score:', f1)
# Out:
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 25s 371ms/step
#                     precision    recall  f1-score   support
#
#        Coccidiosis       0.98      0.97      0.97       372
#            Healthy       0.90      0.93      0.92       361
# New Castle Disease       0.89      0.79      0.84        84
#         Salmonella       0.92      0.92      0.92       394
#
#           accuracy                           0.93      1211
#          macro avg       0.92      0.90      0.91      1211
#       weighted avg       0.93      0.93      0.93      1211
#
# Accuracy: 0.9281585466556564
# Precision: 0.9212209406769383
# Recall: 0.9007669451459093
# F1-Score: 0.9100639759246241

# %%
# Prediksi seluruh test set
y_pred_prob = model.predict(test_gen)
y_pred = np.argmax(y_pred_prob, axis=1)
y_true = test_gen.classes

cm = confusion_matrix(y_true, y_pred)
labels = list(test_gen.class_indices.keys())

plt.figure(figsize=(6,5))
sns.heatmap(cm, annot=True, fmt='d', xticklabels=labels, yticklabels=labels)
plt.xlabel('Predicted'); plt.ylabel('True'); plt.title('Confusion Matrix')
plt.show()
# Out:
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 99ms/step

# %% [markdown]
# ## Save Model

# %%
model.save("denseNet121_model.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
from google.colab import files
files.download("denseNet121_model.h5")

# %%
labels_ordered = list(train_gen.class_indices.keys())
print(labels_ordered)
# Out:
# ['Coccidiosis', 'Healthy', 'New Castle Disease', 'Salmonella']

# %%
labels_by_index = sorted(train_gen.class_indices.items(), key=lambda x: x[1])
labels_by_index = [label for label, idx in labels_by_index]
print("Urutan label output:", labels_by_index)
# Out:
# Urutan label output: ['Coccidiosis', 'Healthy', 'New Castle Disease', 'Salmonella']
