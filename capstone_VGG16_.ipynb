# %% [markdown]
# # ML - Fecalguard
#
# Sumber Dataset: https://www.kaggle.com/datasets/allandclive/chicken-disease-1

# %% [markdown]
# ## Import Library

# %%
import shutil
from google.colab import files

import matplotlib.pyplot as plt
import numpy as np
import os
import shutil
import kagglehub
import io
import pandas as pd
import seaborn as sns
from pathlib import Path
import matplotlib.image as mpimg
import random

from collections import defaultdict, Counter
from PIL import Image

from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image


import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, models, optimizers
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, BatchNormalization
from tensorflow.keras.applications import VGG16
from tensorflow.keras import layers, models, optimizers, Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau

# %% [markdown]
# ## Data Loading

# %%
# Download latest version
path = kagglehub.dataset_download("allandclive/chicken-disease-1")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: /kaggle/input/chicken-disease-1

# %%
df = pd.read_csv('/kaggle/input/chicken-disease-1/train_data.csv')
df.sample(10)
# Out:
#                 images        label
# 5372   healthy.267.jpg      Healthy
# 7418    salmo.1346.jpg   Salmonella
# 7999   healthy.659.jpg      Healthy
# 8007  pcrsalmo.121.jpg   Salmonella
# 1229    cocci.1705.jpg  Coccidiosis
# 7167      salmo.23.jpg   Salmonella
# 1469   pcrsalmo.38.jpg   Salmonella
# 7110  pcrcocci.280.jpg  Coccidiosis
# 6119    salmo.1556.jpg   Salmonella
# 5989  healthy.1961.jpg      Healthy

# %%
df['label'].value_counts()
# Out:
# label
# Salmonella            2625
# Coccidiosis           2476
# Healthy               2404
# New Castle Disease     562
# Name: count, dtype: int64

# %%
# menghitung jumlah data & resolusi data dalam dataset
dataset_path = "/kaggle/input/chicken-disease-1"

# inisialisasi variabel penampung
label_counts = defaultdict(int)
resolution_counter = Counter()
resolution_per_label = defaultdict(set)

# loop menghitung jumlah data & resolusi data dalam dataset
for label in os.listdir(dataset_path):
    label_dir = os.path.join(dataset_path, label)
    if os.path.isdir(label_dir):
        for img_name in os.listdir(label_dir):
            img_path = os.path.join(label_dir, img_name)
            try:
                with Image.open(img_path) as img:
                    label_counts[label] += 1
                    resolution = img.size  # (width, height)
                    resolution_counter[resolution] += 1
                    resolution_per_label[label].add(resolution)
            except Exception as e:
                print(f"Gagal membuka {img_path}: {e}")

# %%
print("\nResolusi gambar dalam dataset:")
for label, resolutions in resolution_per_label.items():
    print(f"{label}: {list(resolutions)}\n")
# Out:
# Resolusi gambar dalam dataset:
# Train: [(224, 224)]

# %%
FOLDER = Path("/kaggle/input/chicken-disease-1/Train")

# ambil semua file JPG, lalu acak
all_images = list(FOLDER.rglob("*.jpg"))      # rglob agar menangkap subfolder per-label
random.shuffle(all_images)
selected = all_images[:10]

plt.figure(figsize=(15,8))
for i, img_path in enumerate(selected, 1):
    img = mpimg.imread(img_path)
    plt.subplot(2,5,i)
    plt.imshow(img); plt.axis("off")
    plt.title(f"{img_path.parent.name}\n{img_path.name}", fontsize=9)  # tampilkan label & nama file
plt.tight_layout(); plt.show()

# %% [markdown]
# ## Data Splitting

# %% [markdown]
# split ratio
#
# train:val:test = 80:15:15

# %%
train_df, test_df = train_test_split(df, test_size=0.15, stratify=df['label'], random_state=42)
train_df, val_df  = train_test_split(train_df, test_size=0.15, stratify=train_df['label'], random_state=42)

print(f"Train {train_df['label'].value_counts()} \n")
print(f"Val {val_df['label'].value_counts()} \n")
print(f"Test {test_df['label'].value_counts()} \n")
# Out:
# Train label
# Salmonella            1896
# Coccidiosis           1788
# Healthy               1737
# New Castle Disease     406
# Name: count, dtype: int64
#
# Val label
# Salmonella            335
# Coccidiosis           316
# Healthy               306
# New Castle Disease     72
# Name: count, dtype: int64
#
# Test label
# Salmonella            394
# Coccidiosis           372
# Healthy               361
# New Castle Disease     84
# Name: count, dtype: int64

# %% [markdown]
# ## Data Augmentation

# %%
df = pd.read_csv('/kaggle/input/chicken-disease-1/train_data.csv')
print(df.columns)
# Out:
# Index(['images', 'label'], dtype='object')

# %%
train_datagen = ImageDataGenerator(
    rescale        = 1./255,
    rotation_range = 20,
    width_shift_range  = 0.1,
    height_shift_range = 0.1,
    shear_range    = 0.1,
    zoom_range     = 0.1,
    horizontal_flip=True
)

val_test_datagen = ImageDataGenerator(rescale=1./255)

train_gen = train_datagen.flow_from_dataframe(
    train_df,
    directory='/kaggle/input/chicken-disease-1/Train',
    x_col='images',
    y_col='label',
    target_size=(244,244),
    class_mode='categorical',
    batch_size=32
)

val_gen = val_test_datagen.flow_from_dataframe(
    val_df, directory='/kaggle/input/chicken-disease-1/Train',
    x_col='images',
    y_col='label',
    target_size=(244,244),
    class_mode='categorical',
    batch_size=32, shuffle=False
)

test_gen = val_test_datagen.flow_from_dataframe(
    test_df, directory='/kaggle/input/chicken-disease-1/Train',
    x_col='images',
    y_col='label',
    target_size=(244,244),
    class_mode='categorical',
    batch_size=32, shuffle=False
)
# Out:
# Found 5827 validated image filenames belonging to 4 classes.
# Found 1029 validated image filenames belonging to 4 classes.
# Found 1211 validated image filenames belonging to 4 classes.

# %% [markdown]
# ## Modelling

# %%
# Membuat base model menggunakan VGG16
base_model = VGG16(weights='imagenet', include_top=False, input_shape=(244, 244, 3), pooling= 'max')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 ━━━━━━━━━━━━━━━━━━━━ 4s 0us/step

# %%
# Membekukan lapisan-lapisan pada base model agar tidak terlatih pada awalnya
base_model.trainable = False

# %%
# Fungsi untuk membangun model CNN dengan VGG16 sebagai base model
def build_cnn_with_vgg16(input_shape=(244, 244, 3), num_classes=4):
    # Memuat model VGG16 tanpa lapisan top (fully connected)
    base_model = VGG16(weights='imagenet', include_top=False, input_shape=input_shape)

    # Membekukan lapisan-lapisan pada base model agar tidak terlatih selama pelatihan awal
    base_model.trainable = False

    # Membangun model Sequential
    model = models.Sequential([
        base_model,  # Menambahkan VGG16 sebagai base model
        layers.GlobalAveragePooling2D(),  # Menggunakan pooling untuk mereduksi dimensi
        layers.Dense(256, activation='relu'),  # Lapisan Dense untuk klasifikasi
        layers.BatchNormalization(),  # Normalisasi untuk stabilitas pelatihan
        layers.Dense(128, activation='relu'),
        layers.Dense(64, activation='relu'),
        layers.Dropout(0.2),  # Dropout untuk mengurangi overfitting
        layers.Dense(num_classes, activation='softmax')  # Lapisan output untuk klasifikasi
    ])

    # Menyusun model
    model.compile(optimizer=Adam(learning_rate=0.0001),
                  loss='categorical_crossentropy',  # Fungsi loss untuk klasifikasi multi-kelas
                  metrics=['accuracy'])

    # Menampilkan ringkasan model
    model.summary()

    return model

# %%
# Membangun model awal
model = build_cnn_with_vgg16()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ vgg16 (Functional)              │ (None, 7, 7, 512)      │    14,714,688 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 512)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 4)              │           260 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 14,888,452 (56.79 MB)
#  Trainable params: 173,252 (676.77 KB)
#  Non-trainable params: 14,715,200 (56.13 MB)

# %%
# Fine-tuning setelah pelatihan awal
base_model.trainable = True

# %%
# Fine-tuning setelah pelatihan awal
# Membuka kembali lapisan-lapisan base model untuk fine-tuning
base_model = model.layers[0]  # Mendapatkan base model MobileNetV2 dari model

base_model.trainable = True

# %%
# Membekukan semua lapisan kecuali 20 lapisan terakhir
for layer in base_model.layers[:-20]:
    layer.trainable = False

# %%
# Menyusun ulang model setelah fine-tuning
model.compile(optimizer=Adam(learning_rate=0.00001),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
history = model.fit(
    train_gen,
    epochs=25,
    validation_data=val_gen,
    callbacks=[
        tf.keras.callbacks.EarlyStopping(patience=5, restore_best_weights=True)
    ]
)
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/25
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 205s 873ms/step - accuracy: 0.6631 - loss: 0.8786 - val_accuracy: 0.7784 - val_loss: 0.7785
# Epoch 2/25
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 136s 740ms/step - accuracy: 0.8627 - loss: 0.4224 - val_accuracy: 0.9077 - val_loss: 0.3430
# Epoch 3/25
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 136s 743ms/step - accuracy: 0.9186 - loss: 0.2816 - val_accuracy: 0.9057 - val_loss: 0.2618
# Epoch 4/25
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 136s 741ms/step - accuracy: 0.9332 - loss: 0.2222 - val_accuracy: 0.9213 - val_loss: 0.2368
# Epoch 5/25
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 135s 739ms/step - accuracy: 0.9531 - loss: 0.1623 - val_accuracy: 0.9174 - val_loss: 0.2437
# Epoch 6/25
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 136s 741ms/step - accuracy: 0.9528 - loss: 0.1593 - val_accuracy: 0.9213 - val_loss: 0.2019
# Epoch 7/25
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 136s 742ms/step - accuracy: 0.9581 - loss: 0.1420 - val_accuracy: 0.9553 - val_loss: 0.1352
# Epoch 8/25
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 135s 738ms/step - accuracy: 0.9670 - loss: 0.1149 - val_accuracy: 0.9524 - val_loss: 0.1315
# Epoch 9/25
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 137s 748ms/step - accuracy: 0.9668 - loss: 0.1039 - val_accuracy: 0.9466 - val_loss: 0.1623
# Epoch 10/25
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 135s 738ms/step - accuracy: 0.9707 - loss: 0.1000 - val_accuracy: 0.9582 - val_loss: 0.1266
# Epoch 11/25
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 138s 753ms/step - accuracy: 0.9722 - loss: 0.0929 - val_accuracy: 0.9397 - val_loss: 0.1725
# Epoch 12/25
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 136s 743ms/step - accuracy: 0.9733 - loss: 0.0893 - val_accuracy: 0.9611 - val_loss: 0.1108
# Epoch 13/25
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 136s 741ms/step - accuracy: 0.9783 - loss: 0.0744 - val_accuracy: 0.9485 - val_loss: 0.1713
# Epoch 14/25
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 137s 748ms/step - accuracy: 0.9844 - loss: 0.0631 - val_accuracy: 0.9504 - val_loss: 0.1512
# Epoch 15/25
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 139s 759ms/step - accuracy: 0.9756 - loss: 0.0758 - val_accuracy: 0.9329 - val_loss: 0.1763
# Epoch 16/25
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 141s 767ms/step - accuracy: 0.9822 - loss: 0.0690 - val_accuracy: 0.9252 - val_loss: 0.2407
# Epoch 17/25
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 138s 753ms/step - accuracy: 0.9851 - loss: 0.0575 - val_accuracy: 0.9670 - val_loss: 0.1066
# Epoch 18/25
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 137s 747ms/step - accuracy: 0.9854 - loss: 0.0512 - val_accuracy: 0.9349 - val_loss: 0.2336
# Epoch 19/25
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 141s 771ms/step - accuracy: 0.9853 - loss: 0.0499 - val_accuracy: 0.9699 - val_loss: 0.1092
# Epoch 20/25
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 137s 746ms/step - accuracy: 0.9757 - loss: 0.0815 - val_accuracy: 0.9456 - val_loss: 0.1851
# Epoch 21/25
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 138s 751ms/step - accuracy: 0.9817 - loss: 0.0587 - val_accuracy: 0.9524 - val_loss: 0.1590
# Epoch 22/25
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 138s 755ms/step - accuracy: 0.9854 - loss: 0.0489 - val_accuracy: 0.9602 - val_loss: 0.1154

# %% [markdown]
# ## Evaluation

# %%
# 1. Evaluasi test set
test_loss, test_acc = model.evaluate(test_gen)
print(f"Test Loss: {test_loss:.4f} | Test Accuracy: {test_acc:.4f}")

# 2. Plot kurva akurasi & loss
epochs_range = range(len(history.history['accuracy']))

plt.figure(figsize=(10,4))

# Accuracy
plt.subplot(1,2,1)
plt.plot(epochs_range, history.history['accuracy'], label='Train')
plt.plot(epochs_range, history.history['val_accuracy'], label='Val')
plt.title('Accuracy per Epoch')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

# Loss
plt.subplot(1,2,2)
plt.plot(epochs_range, history.history['loss'], label='Train')
plt.plot(epochs_range, history.history['val_loss'], label='Val')
plt.title('Loss per Epoch')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 8s 216ms/step - accuracy: 0.9657 - loss: 0.1123
# Test Loss: 0.1107 | Test Accuracy: 0.9661

# %%
from sklearn.metrics import classification_report, accuracy_score, precision_score, recall_score, f1_score

predictions = model.predict(test_gen)

# The predictions will be in a one-hot encoded format, so convert them to labels
predicted_classes = np.argmax(predictions, axis=1)

# Getting the true labels from the generator
true_classes = test_gen.labels

# Getting the class labels from the generator for later use in the classification report
class_labels = list(test_gen.class_indices.keys())

# Calculate and print the classification report
report = classification_report(true_classes, predicted_classes, target_names=class_labels)
accuracy = accuracy_score(true_classes, predicted_classes)

print(report)
print('Accuracy:', accuracy)
# Calculate Precision, Recall, and F1-Score
precision = precision_score(true_classes, predicted_classes, average='macro')
recall = recall_score(true_classes, predicted_classes, average='macro')
f1 = f1_score(true_classes, predicted_classes, average='macro')

print('Precision:', precision)
print('Recall:', recall)
print('F1-Score:', f1)
# Out:
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 21s 547ms/step
#                     precision    recall  f1-score   support
#
#        Coccidiosis       0.99      0.98      0.98       372
#            Healthy       0.95      0.96      0.96       361
# New Castle Disease       0.95      0.92      0.93        84
#         Salmonella       0.96      0.97      0.97       394
#
#           accuracy                           0.97      1211
#          macro avg       0.96      0.96      0.96      1211
#       weighted avg       0.97      0.97      0.97      1211
#
# Accuracy: 0.9661436829066887
# Precision: 0.9632286385148616
# Recall: 0.9564432932796947
# F1-Score: 0.9597338634254211

# %%
# Prediksi seluruh test set
y_pred_prob = model.predict(test_gen)
y_pred = np.argmax(y_pred_prob, axis=1)
y_true = test_gen.classes

cm = confusion_matrix(y_true, y_pred)
labels = list(test_gen.class_indices.keys())

plt.figure(figsize=(6,5))
sns.heatmap(cm, annot=True, fmt='d', xticklabels=labels, yticklabels=labels)
plt.xlabel('Predicted'); plt.ylabel('True'); plt.title('Confusion Matrix')
plt.show()
# Out:
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 8s 204ms/step

# %% [markdown]
# ## Save Model

# %%
model.save("vgg16_model.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
from google.colab import files
files.download("vgg16_model.h5")

# %%
labels_ordered = list(train_gen.class_indices.keys())
print(labels_ordered)
# Out:
# ['Coccidiosis', 'Healthy', 'New Castle Disease', 'Salmonella']

# %%
labels_by_index = sorted(train_gen.class_indices.items(), key=lambda x: x[1])
labels_by_index = [label for label, idx in labels_by_index]
print("Urutan label output:", labels_by_index)
# Out:
# Urutan label output: ['Coccidiosis', 'Healthy', 'New Castle Disease', 'Salmonella']
